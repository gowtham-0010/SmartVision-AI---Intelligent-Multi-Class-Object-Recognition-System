# %%
import os
import cv2
import random
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
DATA_PATH = "../data/classification/train"

# %%
classes = os.listdir(DATA_PATH)
print("Total Classes:", len(classes))
print(classes)
# Out:
# Total Classes: 25
# ['airplane', 'bed', 'bench', 'bicycle', 'bird', 'bottle', 'bowl', 'bus', 'cake', 'car', 'cat', 'chair', 'couch', 'cow', 'cup', 'dog', 'elephant', 'horse', 'motorcycle', 'person', 'pizza', 'potted plant', 'stop sign', 'traffic light', 'truck']

# %%
class_counts = {}

for cls in classes:
    folder = os.path.join(DATA_PATH, cls)
    class_counts[cls] = len(os.listdir(folder))

class_counts
# Out:
# {'airplane': 70,
#  'bed': 70,
#  'bench': 70,
#  'bicycle': 70,
#  'bird': 70,
#  'bottle': 70,
#  'bowl': 70,
#  'bus': 70,
#  'cake': 70,
#  'car': 70,
#  'cat': 70,
#  'chair': 70,
#  'couch': 70,
#  'cow': 70,
#  'cup': 70,
#  'dog': 70,
#  'elephant': 70,
#  'horse': 70,
#  'motorcycle': 70,
#  'person': 70,
#  'pizza': 70,
#  'potted plant': 70,
#  'stop sign': 70,
#  'traffic light': 70,
#  'truck': 70}

# %%
plt.figure(figsize=(12,5))
sns.barplot(x=list(class_counts.keys()), y=list(class_counts.values()))
plt.xticks(rotation=90)
plt.title("Class Distribution")
plt.show()

# %%
plt.figure(figsize=(15,10))

for i, cls in enumerate(classes[:12]):
    
    folder = os.path.join(DATA_PATH, cls)
    img_name = random.choice(os.listdir(folder))
    
    img = cv2.imread(os.path.join(folder, img_name))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    plt.subplot(3,4,i+1)
    plt.imshow(img)
    plt.title(cls)
    plt.axis("off")

plt.show()

# %%
shapes = []

for cls in classes:
    folder = os.path.join(DATA_PATH, cls)
    img_name = random.choice(os.listdir(folder))
    
    img = cv2.imread(os.path.join(folder, img_name))
    shapes.append(img.shape)

set(shapes)
# Out:
# {(224, 224, 3)}

# %%
img = cv2.imread(os.path.join(DATA_PATH, classes[0], os.listdir(os.path.join(DATA_PATH, classes[0]))[0]))

plt.hist(img.ravel(), bins=50)
plt.title("Pixel Intensity Distribution")
plt.show()

# %%
import pandas as pd

df = pd.DataFrame({
    "Class": list(class_counts.keys()),
    "Count": list(class_counts.values())
})

df
# Out:
#             Class  Count
# 0        airplane     70
# 1             bed     70
# 2           bench     70
# 3         bicycle     70
# 4            bird     70
# 5          bottle     70
# 6            bowl     70
# 7             bus     70
# 8            cake     70
# 9             car     70
# 10            cat     70
# 11          chair     70
# 12          couch     70
# 13            cow     70
# 14            cup     70
# 15            dog     70
# 16       elephant     70
# 17          horse     70
# 18     motorcycle     70
# 19         person     70
# 20          pizza     70
# 21   potted plant     70
# 22      stop sign     70
# 23  traffic light     70
# 24          truck     70
